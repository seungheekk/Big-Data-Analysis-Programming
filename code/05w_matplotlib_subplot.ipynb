# %% [markdown]
# <a href="https://colab.research.google.com/github/seungheekk/Big-Data-Analysis-Programming/blob/main/code/05w_matplotlib_subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## plt.subplot() 그림 제목

# %%
# !pip install matplotlib
import koreanize_matplotlib #p.296
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_8583/1853064332.py in <cell line: 0>()
#       1 get_ipython().system('pip install matplotlib')
# ----> 2 import koreanize_matplotlib
#
# ModuleNotFoundError: No module named 'koreanize_matplotlib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %config

# %%
import matplotlib.pyplot as plt
# 전체 제목 - 어느
plt.suptitle('전체 제목', fontsize=14, y=1.02)

#subplot 1 -생성 직후 바로 title 지정
plt.subplot(2, 3, 1)
plt.title([1, 4, 9, 16])
plt.title('제곱수')

# %%
import pandas as pd
import numpy as np

age= pd.Series([9,17, 32,45,65,98], index = list('abcdef'), name='age') #인덱스, 인덱스,
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
int(age['b'])
# Out:
# 17

# %%
age [[1, 3, 5]] #안
# Out:
# /tmp/ipykernel_8583/3593186195.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age [[1, 3, 5]]
# b    17
# d    45
# f    98
# Name: age, dtype: int64

# %%
age[['b','f','a']]
# Out:
# b    17
# f    98
# a     9
# Name: age, dtype: int64

# %%
age[['b','f','a']]
# Out:
# b    17
# f    98
# a     9
# Name: age, dtype: int64

# %%
age[['b','']]

# %%
import matplotlib.pyplot as plt

#방법 1: 함수 rc()로 설정
#rc(runtime configuration)
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
import matplotlib.pyplot as plt
#방법 2: 사전 rcParams[]에 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt


plt.plot([10, 5, 25,30, 20])
plt.title('직선 그래프 그리기: 한글 처리')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([10, 5, 25, 30, 20])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([10, 5, 25, 30, 20])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
plt.rcParams['figure,figsize']
[6.4,4.8]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8583/4142097762.py in <cell line: 0>()
# ----> 1 plt.rcParams['figure,figsize']
#       2 [6.4,4.8]
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in __getitem__(self, key)
#     797                 plt.switch_backend(rcsetup._auto_backend_sentinel)
#     798
# --> 799         return self._get(key)
#     800
#     801     def _get_backend_or_none(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in _get(self, key)
#     715         :meta public:
#     716         """
# --> 717         return dict.__getitem__(self, key)
#     718
#     719     def _update_raw(self, other_params):
#
# KeyError: 'figure,figsize'
